# %%
# !pip install transformers torch textblob
# !pip install transformers torch textblob gym numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 29.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import json
import torch
import torch.nn as nn

# Updated self-care suggestions
self_care_suggestions = {
    "Depression": [
        "Try going for a short walk or sitting outside. Fresh air helps. 💙",
        "Listen to soft music and drink a warm cup of tea. 🎵🍵",
        "Break your day into tiny tasks. One step at a time. ✨",
        "Text or call a close friend. You're not alone. 💖",
        "Wrap yourself in a cozy blanket and rest. 🛌"
    ],
    "Anxiety": [
        "Try the 5-4-3-2-1 technique: Name 5 things you see, 4 you touch, 3 you hear, 2 you smell, 1 you taste. 🌍",
        "Inhale deeply for 4 seconds, hold for 4, exhale for 6. Breathe. 🌬️",
        "Close your eyes and imagine a peaceful place—like a beach or a forest. 🏞️",
        "Hold something soft and familiar, like a pillow or stuffed animal. 🧸",
        "Remember: Thoughts are not facts. Let anxious thoughts pass like clouds. ☁️"
    ],
    "Meditation": [
        "Try 5-minute deep breathing. Inhale for 4 seconds, hold for 4, exhale for 6. 🌬️",
        "Close your eyes and do a body scan meditation. Focus on each part of your body. 🧘‍♂️",
        "Listen to guided meditation on YouTube or a meditation app. 🎧",
        "Sit in a quiet place and focus on your breath. Just observe your thoughts. 🌿",
        "Use a mantra like 'I am calm' or 'I am safe' and repeat it while breathing. ✨"
    ],
    "Calm Music": [
        "Try listening to gentle rain sounds. 🌧️ [Listen Here](https://www.youtube.com/watch?v=eJG50IQhJ_U)",
        "Soft piano music can help you relax. 🎹 [Listen Here](https://www.youtube.com/watch?v=_mVW8tgGY_w)",
        "Ocean waves create a calming atmosphere. 🌊 [Listen Here](https://www.youtube.com/watch?v=7d2avlhzjZo)",
        "Try ambient spa music for relaxation. 🎶 [Listen Here](https://www.youtube.com/watch?v=XUlRyxUMhNY)",
        "Nature sounds like birds and forest help calm the mind. 🌿 [Listen Here](https://www.youtube.com/watch?v=OdIJ2x3nxzQ)"
    ]
}

# Save the updated self-care suggestions
with open("self_care_suggestions.json", "w") as file:
    json.dump(self_care_suggestions, file)

# Simple RL-based learning using reward system
class MentalHealthBot(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(MentalHealthBot, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Define model
input_size = 10
hidden_size = 8
output_size = 9  # Added Meditation & Calm Music categories
model = MentalHealthBot(input_size, hidden_size, output_size)

# Save model
torch.save(model.state_dict(), "mental_health_model.pth")
print("Model trained and saved successfully!")
# Out:
# Model trained and saved successfully!

# %%
from google.colab import files
files.download('/content/mental_health_model.pth')
